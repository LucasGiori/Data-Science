# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasGiori/Data-Science/blob/master/Data_Science_Google_Trends.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %%
pytrend.build_payload(kw_list=['Crise'])

# %%
# Interesse por Região
df = pytrend.interest_by_region()

# %%
df.head(10)
# Out:
#                    Crise
# geoName
# Afghanistan            0
# Albania                0
# Algeria                8
# American Samoa         0
# Andorra                0
# Angola                58
# Anguilla               0
# Antarctica             0
# Antigua & Barbuda      0
# Argentina              0

# %%
df.reset_index().plot(x='geoName', y='Crise', figsize=(120, 10), kind ='bar')

# %% [markdown]
# Principais Tendências de pesquisas diárias

# %%
df = pytrend.trending_searches(pn='brazil') #Se quiser do mundo deixar parâmetro em branco, #united_states
df.head(100)
# Out:
#                                      0
# 0                   Dia do Trabalhador
# 1                       Clara Rockmore
# 2                      Renan Bolsonaro
# 3           Cesta basica do governo sp
# 4                           Quarentena
# 5                    Feriado 1 de maio
# 6                        Quarentena SP
# 7                    Streets of Rage 4
# 8   Quem matou o Max em Avenida Brasil
# 9                          Live cabare
# 10                       Eduardo Leite
# 11                           Petrobras
# 12                         30 de abril
# 13                           Elon Musk
# 14                              Datena
# 15                              Russia
# 16                    Nota Premiada MS
# 17                        Emily Garcia
# 18             Live chitaozinho xororo
# 19                       Ricos de Amor

# %% [markdown]
# Sugestão de palavras chaves a partir de uma palavra

# %%
keywords = pytrend.suggestions(keyword='bolsonaro')
df = pd.DataFrame(keywords)
df.drop(columns= 'mid')   # Excluindo coluna mid retornada
# Out:
#                       title                      type
# 0            Jair Bolsonaro       President of Brazil
# 1          Flávio Bolsonaro      Brazilian Politician
# 2         Eduardo Bolsonaro  Brazilian federal deputy
# 3  Renato Antônio Bolsonaro  Jair Bolsonaro's brother

# %% [markdown]
# Consultas Relacionadas a uma pesquisa..

# %%
pytrend.build_payload (kw_list = ['Coronavirus'])
# Consultas relacionadas, retorna um dicionário de quadros de dados 
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                             query  value
# 0              coronavirus update    100
# 1               coronavirus cases     74
# 2                          corona     67
# 3                news coronavirus     61
# 4   thank you coronavirus helpers     57
# 5            coronavirus symptoms     51
# 6                coronavirus tips     51
# 7                  coronavirus uk     47
# 8               india coronavirus     47
# 9                  el coronavirus     45
# 10                coronavirus map     37
# 11                   corona virus     34
# 12                usa coronavirus     32
# 13              coronavirus china     29
# 14             coronavirus italia     29
# 15             coronavirus france     28
# 16                 us coronavirus     27
# 17               coronavirus live     25
# 18              coronavirus world     25
# 19              italy coronavirus     23
# 20             coronavirus españa     23
# ...

# %% [markdown]
# Tópicos relacionados

# %%
related_topic = pytrend.related_topics()
related_topic.values()
# Out:
# dict_values([{'rising':      value  ...                                  topic_type
# 0   107650  ...                                  Discipline
# 1   104450  ...                                     Website
# 2    98700  ...                    Country in South America
# 3    93400  ...                                      People
# 4    54450  ...                                       Topic
# 5    51950  ...   Private university in Baltimore, Maryland
# 6    49850  ...  Electronics manufacturer in Tempe, Arizona
# 7    40600  ...                                       Topic
# 8    33500  ...                               City in China
# 9    25150  ...                                       Topic
# 10   21550  ...                      Country in the Balkans
# 11   18700  ...                              Italian region
# 12   17900  ...                                       Topic
# 13    2100  ...                           Country in Europe
# ...
